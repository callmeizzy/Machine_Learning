# %% [markdown]
# # 1.Contents :
# - 견종모두포함
#
# # 2. 라이브러리 불러오기

# %%
import numpy as np
import pandas as pd
import os
import glob
import seaborn as sns
import re
import soynlp
sns.set_style('whitegrid', {'grid.linestyle':'--'})
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
import datetime as dt
import warnings 
warnings.filterwarnings('ignore')
# Out:
# C:\Users\LG\AppData\Local\Temp/ipykernel_2788/3573051386.py:12: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('retina')

# %%
def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # Linux(Colab)
        # !apt-get install fonts-nanum -qq  > /dev/null
        # !fc-cache -fv

        import matplotlib as mpl
        mpl.font_manager._rebuild()
        findfont = mpl.font_manager.fontManager.findfont
        mpl.font_manager.findfont = findfont
        mpl.backends.backend_agg.findfont = findfont
        
        font_family = "NanumBarunGothic"
    return font_family

plt.rc("font", family=get_font_family())
plt.rc("axes", unicode_minus=False)

# %%
pd.options.display.max_columns=None

# %% [markdown]
# # 3. 데이터불러오기

# %%
path = glob.glob('data/*.*')
for i in range(len(path)):
    print(i, path[i])
# Out:
# 0 data\animal_raw.csv
# 1 data\관광지.csv
# 2 data\반려견정보.csv

# %%
path[2] # Raw Data Cleansing - 견종데이터(220708).csv
# Out:
# 'data\\반려견정보.csv'

# %%
raw = pd.read_csv(path[2])#, index_col = 0)#, encoding = 'cp949')
df = raw.copy()
df.shape
# Out:
# (7826, 10)

# %% [markdown]
# # 4. 데이터 확인

# %%
df.head()
# Out:
#         품종 크기(체중에따른)  크기(라벨링)  나이  산책시간(시간)    체중   적정음수량 성별 중성화여부  색상
# 0  골든 리트리버         대        2  13       0.5  27.0  1755.0  M     N  갈색
# 1  골든 리트리버         대        2  10       0.5  25.0  1625.0  F     N  갈색
# 2  골든 리트리버         대        2   9       0.5  40.0  2600.0  M     N  갈색
# 3  골든 리트리버         대        2   8       0.5  28.0  1820.0  F     N  갈색
# 4  골든 리트리버         대        2   8       0.5  33.0  2145.0  M     N  갈색

# %%
df.tail()
# Out:
#           품종 크기(체중에따른)  크기(라벨링)  나이  산책시간(시간)    체중   적정음수량 성별 중성화여부     색상
# 7821   핏불테리어         대        2   2       1.5  25.0  1625.0  F     U    검은색
# 7822  화이트테리어         소        0  13       0.5   7.3   474.5  F     Y      흰
# 7823  화이트테리어         소        0   5       1.5   5.0   325.0  F     U     흰색
# 7824      휘펫         중        1   2       1.0  14.0   910.0  M     N    베이지
# 7825      휘펫         중        1   2       1.0  19.5  1267.5  F     U  검/갈/흰

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7826 entries, 0 to 7825
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   품종         7826 non-null   object
#  1   크기(체중에따른)  7826 non-null   object
#  2   크기(라벨링)    7826 non-null   int64
#  3   나이         7826 non-null   int64
#  4   산책시간(시간)   7826 non-null   float64
#  5   체중         7826 non-null   float64
#  6   적정음수량      7826 non-null   float64
#  7   성별         7826 non-null   object
#  8   중성화여부      7826 non-null   object
#  9   색상         7826 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 611.5+ KB

# %%
df.isnull().sum()
# Out:
# 품종           0
# 크기(체중에따른)    0
# 크기(라벨링)      0
# 나이           0
# 산책시간(시간)     0
# 체중           0
# 적정음수량        0
# 성별           0
# 중성화여부        0
# 색상           0
# dtype: int64

# %%
df['품종'].nunique()
# Out:
# 83

# %%
df['품종'].unique()
# Out:
# array(['골든 리트리버', '그레이 하운드', '그레이트 덴', '그레이트피레니즈', '네오폴리탄 마스티프', '닥스훈트',
#        '달마시안', '도베르만', '도사', '동경견', '라브라도리트리버', '라사 압소', '라이카', '로트와일러',
#        '마리노이즈', '말라뮤트', '말티즈', '미니어쳐 푸들', '미니어쳐슈나우저', '미니어쳐핀셔', '믹스견',
#        '바센지', '바셋 하운드', '버니즈 마운틴 독', '베들링턴 테리어', '보더콜리', '보르조이', '보스턴테리어',
#        '불 테리어', '불독', '브리타니 스파니엘', '비글', '비숑 프리제', '빠삐용', '사모예드', '삽살',
#        '샤페이', '세인트 버나드', '셔틀랜드 쉽독', '셰퍼드', '슈나우져', '스코티쉬 테리어', '스탠다드 푸들',
#        '스피츠', '시바견', '시베리안허스키', '시츄', '아메리칸 아키다', '아메리칸 코카 스파니엘',
#        '아메리칸 핏불 테리어', '아메리칸불리', '아프간 하운드', '알라스칸 말라뮤트', '올드 잉글리쉬 쉽독',
#        '요크셔 테리어', '울프독', '웰시코기', '이탈리안 그레이 하운드', '잉글리쉬 세터', '잭 러셀 테리어',
#        '제페니즈칭', '진도견', '차우차우', '치와와', '카네코르소', '캐벌리어 킹 찰스 스파니엘', '케인 코르소',
#        '코리아 트라이 하운드', '코카스파니엘', '콜리', '토이 푸들', '티베탄 마스티프', '퍼그', '페키니즈',
#        '포메라니안', '포인터', '폼피츠', '푸들', '풍산견', '프렌치불독', '핏불테리어', '화이트테리어',
#        '휘펫'], dtype=object)

# %%
df['품종'].value_counts()
# Out:
# 믹스견            5738
# 말티즈             348
# 푸들              302
# 포메라니안           167
# 진도견             148
#                ...
# 아메리칸 핏불 테리어       1
# 아프간 하운드           1
# 제페니즈칭             1
# 잭 러셀 테리어          1
# 스코티쉬 테리어          1
# Name: 품종, Length: 83, dtype: int64

# %%
df['크기(체중에따른)'].value_counts()
# Out:
# 소    5503
# 중    1715
# 대     608
# Name: 크기(체중에따른), dtype: int64

# %%
df['크기(라벨링)'].value_counts()
# Out:
# 0    5503
# 1    1715
# 2     608
# Name: 크기(라벨링), dtype: int64

# %% [markdown]
# # 5. 데이터 정리(cleansing)

# %%
df.head()
# Out:
#         품종 크기(체중에따른)  크기(라벨링)  나이  산책시간(시간)    체중   적정음수량 성별 중성화여부  색상
# 0  골든 리트리버         대        2  13       0.5  27.0  1755.0  M     N  갈색
# 1  골든 리트리버         대        2  10       0.5  25.0  1625.0  F     N  갈색
# 2  골든 리트리버         대        2   9       0.5  40.0  2600.0  M     N  갈색
# 3  골든 리트리버         대        2   8       0.5  28.0  1820.0  F     N  갈색
# 4  골든 리트리버         대        2   8       0.5  33.0  2145.0  M     N  갈색

# %%
df.columns
# Out:
# Index(['품종', '크기(체중에따른)', '크기(라벨링)', '나이', '산책시간(시간)', '체중', '적정음수량', '성별',
#        '중성화여부', '색상'],
#       dtype='object')

# %% [markdown]
# - 데이터 정리
# ['품종', '크기(체중에따른)', '크기(라벨링)', '나이', '산책시간(시간)', '체중', '적정음수량']

# %%
# 성별, 중성화여부는 제외하자 - 결측치를 다루기엔 데이터가 많음 - 그리고 범주형이라 어짜피 빼야함 
df1 = df[['품종','크기(라벨링)', '나이', '산책시간(시간)', '체중', '적정음수량']]

# %%
df1.head()
# Out:
#         품종  크기(라벨링)  나이  산책시간(시간)    체중   적정음수량
# 0  골든 리트리버        2  13       0.5  27.0  1755.0
# 1  골든 리트리버        2  10       0.5  25.0  1625.0
# 2  골든 리트리버        2   9       0.5  40.0  2600.0
# 3  골든 리트리버        2   8       0.5  28.0  1820.0
# 4  골든 리트리버        2   8       0.5  33.0  2145.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7826 entries, 0 to 7825
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   품종        7826 non-null   object
#  1   크기(라벨링)   7826 non-null   int64
#  2   나이        7826 non-null   int64
#  3   산책시간(시간)  7826 non-null   float64
#  4   체중        7826 non-null   float64
#  5   적정음수량     7826 non-null   float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 367.0+ KB

# %%
plt.figure(figsize = (8, 5))
sns.heatmap(df1.isnull())
plt.show()

# %%
df1.describe()
# Out:
#            크기(라벨링)           나이     산책시간(시간)           체중        적정음수량
# count  7826.000000  7826.000000  7826.000000  7826.000000  7826.000000
# mean      0.374521     2.099540     0.897304     7.794053   506.613455
# std       0.624247     2.647694     0.168873     6.967980   452.918710
# min       0.000000     0.000000     0.500000     0.040000     2.600000
# 25%       0.000000     0.000000     0.800000     3.000000   195.000000
# 50%       0.000000     1.000000     1.000000     5.000000   325.000000
# 75%       1.000000     3.000000     1.000000    11.000000   715.000000
# max       2.000000    18.000000     1.500000    60.000000  3900.000000

# %%
df1.hist(figsize = (12,8))
plt.show()

# %% [markdown]
# - 품종, 크기 컬럼은 따로 빼놓자

# %%
kind = df1['품종']
size = df1['크기(라벨링)']

# %%
print(kind,size)
# Out:
# 0       골든 리트리버
# 1       골든 리트리버
# 2       골든 리트리버
# 3       골든 리트리버
# 4       골든 리트리버
#          ...
# 7821      핏불테리어
# 7822     화이트테리어
# 7823     화이트테리어
# 7824         휘펫
# 7825         휘펫
# Name: 품종, Length: 7826, dtype: object 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 7821    2
# 7822    0
# 7823    0
# 7824    1
# 7825    1
# Name: 크기(라벨링), Length: 7826, dtype: int64

# %%
del df1['품종']
# del df1['크기(라벨링)']

# %%
# 전처리 데이터저장
# df1.to_csv('./pre_dog_data_0708.csv')

# %%
# 저장확인
# pd.read_csv('./pre_dog_data_0708.csv', index_col = 0)

# %% [markdown]
# # 6. Feature Extraction

# %%
df1.head()
# Out:
#    크기(라벨링)  나이  산책시간(시간)    체중   적정음수량
# 0        2  13       0.5  27.0  1755.0
# 1        2  10       0.5  25.0  1625.0
# 2        2   9       0.5  40.0  2600.0
# 3        2   8       0.5  28.0  1820.0
# 4        2   8       0.5  33.0  2145.0

# %%
corr_bar = []

for column in df1.columns:
    print(f"{column}과 크기의 상관관계:{df1[column].corr(df1['크기(라벨링)'])}")
    corr_bar.append(df1[column].corr(df1['크기(라벨링)']))
# Out:
# 크기(라벨링)과 크기의 상관관계:1.0
# 나이과 크기의 상관관계:0.16231373343385744
# 산책시간(시간)과 크기의 상관관계:0.4715765295369687
# 체중과 크기의 상관관계:0.9169479589896972
# 적정음수량과 크기의 상관관계:0.9169479589896975

# %%
plt.figure(figsize = (15,8))
sns.barplot(df1.columns, corr_bar)
plt.show()

# %%
# 크기 삭제
del df1['크기(라벨링)']

# %% [markdown]
# # 7. ElbowPoint

# %%
# 군집화 라이브러리 불러오기 .
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

# %%
data = df1

# %%
from sklearn.cluster import KMeans

# %%
x = [] #k가 몇개인지 -
y = [] #응집도가 몇인지 

# 범위가 1~30인 이유
for k in range (1,30): 
    kmeans = KMeans(n_clusters = k) # 1~ 29개의 군집화 된 객체를 kmeans라고 함   
    kmeans.fit(data)               # kmeans에다가 data2를 학습시킬것임 
    
    x.append(k)
    y.append(kmeans.inertia_)

    
#k가 n개 일 때 응집도는 a라고 이해하면 된다

# %%
# 그래프 그리기
plt.figure(figsize = (15,8))
plt.plot(x, y)
plt.show()

# %% [markdown]
# # 9.군집화(k=3)

# %%
# 3개로 군집화 된 객체를 생성 
kmeans = KMeans(n_clusters = 3)

# %%
# 군집화 할 데이터 'data2'를 학습시키기 
kmeans.fit(data)
# Out:
# KMeans(n_clusters=3)

# %%
# 학습된 kmeans의 응집도 확인 (각 데이터로부터 자신이 속한 군집의 중심까지의 거리)
# 응집도가 낮을수록 군집화가 더 잘되어있는 것이다

# %%
#각 군집 별 중앙 값 
print(kmeans.cluster_centers_[0])
print(kmeans.cluster_centers_[1])
print(kmeans.cluster_centers_[2]) # 얘는 뒤에 e가 붙어서 "*10" 으로 계산해줘야 함
# Out:
# [  2.47270855   0.97358393  12.95593718 842.13591658]
# [  1.80572087   0.84378959   3.72818967 242.33232866]
# [3.29333333e+00 1.09081481e+00 2.43195407e+01 1.58077015e+03]

# %%
data
# Out:
#       나이  산책시간(시간)    체중   적정음수량
# 0     13       0.5  27.0  1755.0
# 1     10       0.5  25.0  1625.0
# 2      9       0.5  40.0  2600.0
# 3      8       0.5  28.0  1820.0
# 4      8       0.5  33.0  2145.0
# ...   ..       ...   ...     ...
# 7821   2       1.5  25.0  1625.0
# 7822  13       0.5   7.3   474.5
# 7823   5       1.5   5.0   325.0
# 7824   2       1.0  14.0   910.0
# 7825   2       1.0  19.5  1267.5
#
# [7826 rows x 4 columns]

# %%
data['labels'] = kmeans.predict(data)

# %%
data.head()
# Out:
#    나이  산책시간(시간)    체중   적정음수량  labels
# 0  13       0.5  27.0  1755.0       2
# 1  10       0.5  25.0  1625.0       2
# 2   9       0.5  40.0  2600.0       2
# 3   8       0.5  28.0  1820.0       2
# 4   8       0.5  33.0  2145.0       2

# %%
data['labels'].value_counts()
# Out:
# 1    5209
# 0    1942
# 2     675
# Name: labels, dtype: int64

# %%
scaler = StandardScaler()
scaler_data = scaler.fit_transform(data)

# %%
tsne = TSNE()

# %%
data_tsne = pd.DataFrame(data = tsne.fit_transform(scaler_data), columns = ['tsne1', 'tsne2'])

# %%
data_tsne['labels'] = data['labels']

# %%
plt.figure(figsize = (15,8))
sns.scatterplot(x = 'tsne1', y = 'tsne2', hue = 'labels', data = data_tsne)
plt.show()

# %% [markdown]
# # 10.결과해석 & 시각화
# ## (1) 앞에 빼놨던 컬럼 붙이기

# %%
data
# Out:
#       나이  산책시간(시간)    체중   적정음수량  labels
# 0     13       0.5  27.0  1755.0       2
# 1     10       0.5  25.0  1625.0       2
# 2      9       0.5  40.0  2600.0       2
# 3      8       0.5  28.0  1820.0       2
# 4      8       0.5  33.0  2145.0       2
# ...   ..       ...   ...     ...     ...
# 7821   2       1.5  25.0  1625.0       2
# 7822  13       0.5   7.3   474.5       1
# 7823   5       1.5   5.0   325.0       1
# 7824   2       1.0  14.0   910.0       0
# 7825   2       1.0  19.5  1267.5       2
#
# [7826 rows x 5 columns]

# %%
df1
# Out:
#       나이  산책시간(시간)    체중   적정음수량  labels
# 0     13       0.5  27.0  1755.0       2
# 1     10       0.5  25.0  1625.0       2
# 2      9       0.5  40.0  2600.0       2
# 3      8       0.5  28.0  1820.0       2
# 4      8       0.5  33.0  2145.0       2
# ...   ..       ...   ...     ...     ...
# 7821   2       1.5  25.0  1625.0       2
# 7822  13       0.5   7.3   474.5       1
# 7823   5       1.5   5.0   325.0       1
# 7824   2       1.0  14.0   910.0       0
# 7825   2       1.0  19.5  1267.5       2
#
# [7826 rows x 5 columns]

# %%
df1['크기'] = size
df1['품종'] = kind
df1['labels'] = data['labels']

# %%
df1.head()
# Out:
#    나이  산책시간(시간)    체중   적정음수량  labels  크기       품종
# 0  13       0.5  27.0  1755.0       2   2  골든 리트리버
# 1  10       0.5  25.0  1625.0       2   2  골든 리트리버
# 2   9       0.5  40.0  2600.0       2   2  골든 리트리버
# 3   8       0.5  28.0  1820.0       2   2  골든 리트리버
# 4   8       0.5  33.0  2145.0       2   2  골든 리트리버

# %%
df1.columns.to_list()
# Out:
# ['나이', '산책시간(시간)', '체중', '적정음수량', 'labels', '크기', '품종']

# %%
df1 = df1[['품종', '크기', '나이', '산책시간(시간)', '체중', '적정음수량', 'labels']]

# %%
df1.head()
# Out:
#         품종  크기  나이  산책시간(시간)    체중   적정음수량  labels
# 0  골든 리트리버   2  13       0.5  27.0  1755.0       2
# 1  골든 리트리버   2  10       0.5  25.0  1625.0       2
# 2  골든 리트리버   2   9       0.5  40.0  2600.0       2
# 3  골든 리트리버   2   8       0.5  28.0  1820.0       2
# 4  골든 리트리버   2   8       0.5  33.0  2145.0       2

# %% [markdown]
# ## (2) 그룹별 갯수 시각화

# %%
(df1['labels'].value_counts(normalize = True)*100).round(1)
# Out:
# 1    66.6
# 0    24.8
# 2     8.6
# Name: labels, dtype: float64

# %%
(df1['labels'].value_counts(normalize = True)*100).round(1).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## (3) 그룹별 평균 크기 비교

# %%
# 시각화를 위해서 각 그룹별 size을 따로 변수로 생성
size0 = df1[df1['labels'] == 0]['크기'].mean()
size1 = df1[df1['labels'] == 1]['크기'].mean()
size2 = df1[df1['labels'] == 2]['크기'].mean()

# %%
# 주의 모든 과정을 똑같이 하였어도 kmeans의 기본 중심값 설정은 랜덤임
plt.figure(figsize = (15,8))
sns.barplot(x = ['group_0', 'group_1', 'group_2'], y = [size0, size1, size2] )
plt.show()

# %% [markdown]
# ## (4) 그룹별 평균 나이 비교

# %%
# 시각화를 위해서 각 그룹별 size을 따로 변수로 생성
age0 = df1[df1['labels'] == 0]['나이'].mean()
age1 = df1[df1['labels'] == 1]['나이'].mean()
age2 = df1[df1['labels'] == 2]['나이'].mean()
# 주의 모든 과정을 똑같이 하였어도 kmeans의 기본 중심값 설정은 랜덤임
plt.figure(figsize = (15,8))
sns.barplot(x = ['group_0', 'group_1', 'group_2'], y = [age0, age1, age2] )
plt.show()

# %% [markdown]
# ## (5) 그룹별 평균 체중비교

# %%
# 시각화를 위해서 각 그룹별 size을 따로 변수로 생성
wgt0 = df1[df1['labels'] == 0]['체중'].mean()
wgt1 = df1[df1['labels'] == 1]['체중'].mean()
wgt2 = df1[df1['labels'] == 2]['체중'].mean()
# 주의 모든 과정을 똑같이 하였어도 kmeans의 기본 중심값 설정은 랜덤임
plt.figure(figsize = (15,8))
sns.barplot(x = ['group_0', 'group_1', 'group_2'], y = [wgt0, wgt1, wgt2] )
plt.show()

# %% [markdown]
# ## (6) 그룹별 평균 권장 산책시간 비교

# %%
# 시각화를 위해서 각 그룹별 size을 따로 변수로 생성
recom0 = df1[df1['labels'] == 0]['산책시간(시간)'].mean()
recom1 = df1[df1['labels'] == 1]['산책시간(시간)'].mean()
recom2 = df1[df1['labels'] == 2]['산책시간(시간)'].mean()
# 주의 모든 과정을 똑같이 하였어도 kmeans의 기본 중심값 설정은 랜덤임
plt.figure(figsize = (15,8))
sns.barplot(x = ['group_0', 'group_1', 'group_2'], y = [recom0, recom1, recom2] )
plt.show()

# %% [markdown]
# ## (7)그룹별 특징
# - 나이를 기준으로 비교

# %%
df1.head()
# Out:
#         품종  크기  나이  산책시간(시간)    체중   적정음수량  labels
# 0  골든 리트리버   2  13       0.5  27.0  1755.0       2
# 1  골든 리트리버   2  10       0.5  25.0  1625.0       2
# 2  골든 리트리버   2   9       0.5  40.0  2600.0       2
# 3  골든 리트리버   2   8       0.5  28.0  1820.0       2
# 4  골든 리트리버   2   8       0.5  33.0  2145.0       2

# %%
group = df1[(df1['labels']==0) | (df1['labels']==1) | (df1['labels']==2) ]

# %%
group['labels'].value_counts()
# Out:
# 1    5209
# 0    1942
# 2     675
# Name: labels, dtype: int64

# %%
group = group.groupby('labels').mean().reset_index()
group
# Out:
#    labels        크기        나이  산책시간(시간)         체중        적정음수량
# 0       0  0.848610  2.472709  0.973584  12.955937   842.135917
# 1       1  0.000000  1.805721  0.843790   3.728190   242.332329
# 2       2  1.900741  3.293333  1.090815  24.319541  1580.770148

# %%
column = group.columns
column
# Out:
# Index(['labels', '크기', '나이', '산책시간(시간)', '체중', '적정음수량'], dtype='object')

# %%
# 반복문으로 그림그리기
f, ax = plt.subplots(2,3,figsize=(20,13))

for i in range(1,6):
        sns.barplot(x='labels', y=column[i], data=group, ax = ax[i//3, i%3])

# sns.barplot(x='labels', y='크기', data = group, ax = ax[0,0])
# sns.barplot(x='labels', y='나이', data = group, ax = ax[0,1])
# sns.barplot(x='labels', y='체중', data = group, ax = ax[1,0])

plt.show()

# %%
df1[df1['labels']==0].describe()
# Out:
#                 크기           나이     산책시간(시간)           체중        적정음수량  labels
# count  1942.000000  1942.000000  1942.000000  1942.000000  1942.000000  1942.0
# mean      0.848610     2.472709     0.973584    12.955937   842.135917     0.0
# std       0.358521     1.898514     0.120652     2.894351   188.132820     0.0
# min       0.000000     0.000000     0.500000     8.360000   543.400000     0.0
# 25%       1.000000     1.000000     1.000000    10.000000   650.000000     0.0
# 50%       1.000000     2.000000     1.000000    13.000000   845.000000     0.0
# 75%       1.000000     3.000000     1.000000    15.000000   975.000000     0.0
# max       1.000000    15.000000     1.500000    18.500000  1202.500000     0.0

# %%
df1[df1['labels']==1].describe()
# Out:
#            크기           나이     산책시간(시간)           체중        적정음수량  labels
# count  5209.0  5209.000000  5209.000000  5209.000000  5209.000000  5209.0
# mean      0.0     1.805721     0.843790     3.728190   242.332329     1.0
# std       0.0     2.898812     0.141028     2.026578   131.727590     0.0
# min       0.0     0.000000     0.500000     0.040000     2.600000     1.0
# 25%       0.0     0.000000     0.800000     2.070000   134.550000     1.0
# 50%       0.0     0.000000     0.800000     3.400000   221.000000     1.0
# 75%       0.0     3.000000     1.000000     5.000000   325.000000     1.0
# max       0.0    18.000000     1.500000     8.320000   540.800000     1.0

# %%
df1[df1['labels']==2].describe()
# Out:
#                크기          나이    산책시간(시간)          체중        적정음수량  labels
# count  675.000000  675.000000  675.000000  675.000000   675.000000   675.0
# mean     1.900741    3.293333    1.090815   24.319541  1580.770148     2.0
# std      0.299232    1.892481    0.243073    5.458604   354.809286     0.0
# min      1.000000    0.000000    0.500000   18.700000  1215.500000     2.0
# 25%      2.000000    2.000000    1.000000   20.000000  1300.000000     2.0
# 50%      2.000000    3.000000    1.000000   23.000000  1495.000000     2.0
# 75%      2.000000    4.000000    1.000000   26.990000  1754.350000     2.0
# max      2.000000   14.000000    1.500000   60.000000  3900.000000     2.0

# %%
df1.head()
# Out:
#         품종  크기  나이  산책시간(시간)    체중   적정음수량  labels
# 0  골든 리트리버   2  13       0.5  27.0  1755.0       2
# 1  골든 리트리버   2  10       0.5  25.0  1625.0       2
# 2  골든 리트리버   2   9       0.5  40.0  2600.0       2
# 3  골든 리트리버   2   8       0.5  28.0  1820.0       2
# 4  골든 리트리버   2   8       0.5  33.0  2145.0       2

# %%
df1[df1['labels'] == 0]['품종'].value_counts().head(20)
# Out:
# 믹스견        1521
# 진도견          66
# 시바견          45
# 웰시코기         37
# 프렌치불독        31
# 보더콜리         23
# 스피츠          17
# 코카스파니엘       15
# 푸들           15
# 시베리안허스키      13
# 비글           11
# 포인터          11
# 사모예드         11
# 퍼그            9
# 불독            8
# 보스턴테리어        8
# 슈나우져          7
# 삽살            7
# 비숑 프리제        6
# 골든 리트리버       6
# Name: 품종, dtype: int64

# %%
df1[df1['labels'] == 1]['품종'].value_counts().head(20)
# Out:
# 믹스견         3884
# 말티즈          347
# 푸들           287
# 포메라니안        166
# 시츄            74
# 치와와           71
# 요크셔 테리어       47
# 비숑 프리제        43
# 닥스훈트          41
# 스피츠           36
# 진도견           31
# 풍산견           21
# 시바견           21
# 프렌치불독         18
# 슈나우져          14
# 미니어쳐핀셔        11
# 웰시코기          10
# 라브라도리트리버       9
# 코카스파니엘         6
# 베들링턴 테리어       6
# Name: 품종, dtype: int64

# %%
df1[df1['labels'] == 2]['품종'].value_counts().head(20)
# Out:
# 믹스견         333
# 라브라도리트리버     77
# 골든 리트리버      60
# 진도견          51
# 시베리안허스키      22
# 셰퍼드          15
# 풍산견          14
# 도사           12
# 말라뮤트         11
# 보더콜리          9
# 포인터           8
# 도베르만          6
# 차우차우          4
# 아메리칸불리        4
# 사모예드          4
# 삽살            4
# 스탠다드 푸들       3
# 로트와일러         3
# 그레이트피레니즈      3
# 케인 코르소        2
# Name: 품종, dtype: int64

# %%
data_dog = df1.groupby('labels')('품종').nunique()
data_dog
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2788/1732316120.py in <module>
# ----> 1 data_dog = df1.groupby('labels')('품종').nunique()
#       2 data_dog
#
# TypeError: 'DataFrameGroupBy' object is not callable

# %%
data_dog[data_dog['labels'] == 0]['품종'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2788/1913707124.py in <module>
# ----> 1 data_dog[data_dog['labels'] == 0]['품종'].value_counts()
#
# NameError: name 'data_dog' is not defined

# %%
df1.head()
# Out:
#         품종  크기  나이  산책시간(시간)    체중   적정음수량  labels
# 0  골든 리트리버   2  13       0.5  27.0  1755.0       2
# 1  골든 리트리버   2  10       0.5  25.0  1625.0       2
# 2  골든 리트리버   2   9       0.5  40.0  2600.0       2
# 3  골든 리트리버   2   8       0.5  28.0  1820.0       2
# 4  골든 리트리버   2   8       0.5  33.0  2145.0       2

# %%
df1[df1['labels']==1].describe()
# Out:
#            크기           나이     산책시간(시간)           체중        적정음수량  labels
# count  5209.0  5209.000000  5209.000000  5209.000000  5209.000000  5209.0
# mean      0.0     1.805721     0.843790     3.728190   242.332329     1.0
# std       0.0     2.898812     0.141028     2.026578   131.727590     0.0
# min       0.0     0.000000     0.500000     0.040000     2.600000     1.0
# 25%       0.0     0.000000     0.800000     2.070000   134.550000     1.0
# 50%       0.0     0.000000     0.800000     3.400000   221.000000     1.0
# 75%       0.0     3.000000     1.000000     5.000000   325.000000     1.0
# max       0.0    18.000000     1.500000     8.320000   540.800000     1.0

# %%
df1[df1['labels']==0].std().plot()
# Out:
# <AxesSubplot:>

# %%
df1.describe()
# Out:
#                 크기           나이     산책시간(시간)           체중        적정음수량  \
# count  7826.000000  7826.000000  7826.000000  7826.000000  7826.000000
# mean      0.374521     2.099540     0.897304     7.794053   506.613455
# std       0.624247     2.647694     0.168873     6.967980   452.918710
# min       0.000000     0.000000     0.500000     0.040000     2.600000
# 25%       0.000000     0.000000     0.800000     3.000000   195.000000
# 50%       0.000000     1.000000     1.000000     5.000000   325.000000
# 75%       1.000000     3.000000     1.000000    11.000000   715.000000
# max       2.000000    18.000000     1.500000    60.000000  3900.000000
#
#             labels
# count  7826.000000
# mean      0.838104
# std       0.555182
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000

# %%
plt.figure(figsize=(12,8))
df1[df1['labels']==0]['체중'].hist()
plt.show()

# %%
plt.figure(figsize=(12,8))
df1[df1['labels']==1]['체중'].hist()
plt.show()

# %%
plt.figure(figsize=(12,8))
df1[df1['labels']==2]['체중'].hist()
plt.show()
